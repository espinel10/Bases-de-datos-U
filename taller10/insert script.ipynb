# %%
import random
from random import randint, seed
names = ["Stanley","Miranda",
"Kimberly","Reyna",
"Romario","Guest",
"LilyMai","Blake",
"Desiree","Velazquez",
"Shae","Fraser",
"Regan","Bell",
"Tulisa","Yu",
"Cadence","Macgregor",
"Rhonda","Galindo",
"Yahya","Nunez",
"Claude","Phan",
"Bertie","Ashley",
"Talia","Lutz",
"Khia","Jarvis",
"Percy","Summers",
"Ayaan","Frederick",
"Adele","Mccartney",
"Landon","Harmon",
"Haleemah","Fry",
"Ismaeel","Charles",
"Giles","Hodges",
"LexiMae","Gibbons",
"Annabell","Walsh",
"Lamar","Ferrell",
"Leopold","Clayton",
"Umer",
"Loki","Herrera",
"Rebecca","Chaney",
"Celia","Cortes",
"Muhamed","Lynn",
"Penny","Hays",
"Ianis","Lara",
"Keaton","Clegg",
"Rick","Daly",
"Krish","Rangel",
"Jaeden","Read",
"Kayla","Ventura",
"Rosa","Dickson",
"Laurel"," Knox",
"Umaiza","Felix",
"Amalie","Combs"]
maquinas= ["Pump it up", "Dance dance revolution", "In the groove","High Noon","COD","TFT","Car race","Hammer time","Basket star"]

atracciones=["Montaña rusa","Escalada extrema","Carros chocones","Circus chuck","Realidad aumentada","Circuito tematico"]

sucursales=["Bogota Fantasylandia", "Bucaramanga Fantasylandia","WuHan Fantasylandia"]

tablas= {"atraccion":"(idatraccion,nombre,descripcion)" ,
        "cliente":"(idcliente,idtarjeta,nombre,correo,telefono,apelido)",
        "detalle":"(iddetalle,info)",
        "empleado":"(idempleado,fechaingreso,nombre,apellido)",
        "factura": "(idfactura,idempleado,iddetalle,fecha)",
        "mantenimiento":"(idmantenimiento,idtipomantenimiento,idmaquina,fecha,descripcion)",
        "maquina":"(idmaquina,idproveedor,nombre)",
        "pago_tarjeta":"(idpagotarjeta,idtarjeta,fecha,descripcion)",
        "proveedor":"(idproveedor,nombre,direccion,telefono,correo)",
        "recarga":"(idrecarga,idcliente,idtarjeta,idfactura,valor,fecha)",
        "restaurante":"(idrestaurante,idsucursal,idempleado,descripcion)",
        "sucursal":"(idsucursal,nombre,descripcion)",
        "sucursal_atraccion":"(idsucursalatraccion,idturno,idpagotarjetas,idsucursal,precio)",
        "sucursal_maquina":"(idsucursalmaquina,idturno,idpagotarjetas,idsucursal,precio)",
        "tarjeta":"(idtarjeta,saldo)",
        "tipo_mantenimiento":"(idtipomantenimiento,preventivo,correctivo)",
        "turno":"(idturno,idempleado,h_inicio,h_final)"}
llaves= []
for key in tablas:
    llaves.append(key)
    
inserts=[i,desc(),date(),telef()]
def desc():
    return "'"+"No hay descripción disponible"+"'"
def date():
  
    ms= str(randint(2000,2020)) + "-"+str(randint(1,12))+"-"+str(randint(1,29))
    return ms
def telef():
    me=randint(0,8)
    m0=randint(1000000,9999999)
    return str(31)+str(randint(0,10))+str(me)+str(m0)
def money():
    return randint(0,2000000)
def correo(lista):
    return "'"+namegen(lista)+str(randint(1,20))+"@gmail.com"+"'"

def namegen(lista):
    return random.choice(lista)
def insertinto():
    return "INSERT INTO"
def proyectodb (key,table,index):
    msg= "proyectodb."+ key[index]+" "+table[key[index]]
    return msg

for i in range(0,100):
    
 print(insertinto() + " "+ proyectodb(llaves,tablas,13) + " VALUES("+str(i)+","+str(i)+","+str(i)+","+str(i)+","+str(randint(0,2))+","+str(money())+");")
# Out:
# INSERT INTO proyectodb.sucursal_maquina (idsucursalmaquina,idturno,idpagotarjetas,idsucursal,precio) VALUES(0,0,0,0,1,135400);
# INSERT INTO proyectodb.sucursal_maquina (idsucursalmaquina,idturno,idpagotarjetas,idsucursal,precio) VALUES(1,1,1,1,1,256777);
# INSERT INTO proyectodb.sucursal_maquina (idsucursalmaquina,idturno,idpagotarjetas,idsucursal,precio) VALUES(2,2,2,2,0,122420);
# INSERT INTO proyectodb.sucursal_maquina (idsucursalmaquina,idturno,idpagotarjetas,idsucursal,precio) VALUES(3,3,3,3,0,1577754);
# INSERT INTO proyectodb.sucursal_maquina (idsucursalmaquina,idturno,idpagotarjetas,idsucursal,precio) VALUES(4,4,4,4,2,516753);
# INSERT INTO proyectodb.sucursal_maquina (idsucursalmaquina,idturno,idpagotarjetas,idsucursal,precio) VALUES(5,5,5,5,0,452864);
# INSERT INTO proyectodb.sucursal_maquina (idsucursalmaquina,idturno,idpagotarjetas,idsucursal,precio) VALUES(6,6,6,6,0,947262);
# ...
